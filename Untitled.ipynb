# %%
# 1. 깃 저장소 초기화 (프로젝트 폴더 최상단에서 실행)
# !git init

# 2. 깃허브 연동을 위한 기본 정보 설정 (본인의 깃허브 정보로 수정)
# !git config --global user.name "jjeong"
# !git config --global user.email "dattery528@gmail.com"

# 3. A단계까지 만들어진 모든 파일을 장바구니에 담기
# !git add .

# 4. 첫 번째 커밋(저장) 남기기
# !git commit -m "chore: 프로젝트 초기 세팅 및 A단계 완료"
# Out:
# 힌트: Using 'master' as the name for the initial branch. This default branch name
# 힌트: is subject to change. To configure the initial branch name to use in all
# 힌트: of your new repositories, which will suppress this warning, call:
# 힌트:
# 힌트: 	git config --global init.defaultBranch <name>
# 힌트:
# 힌트: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# 힌트: 'development'. The just-created branch can be renamed via this command:
# 힌트:
# 힌트: 	git branch -m <name>
# /home/jovyan/work/DopamineCat/.git/ 안의 빈 깃 저장소를 다시 초기화했습니다
# [master (최상위-커밋) 69b217c] chore: 프로젝트 초기 세팅 및 A단계 완료
#  32 files changed, 1156 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb
#  create mode 100644 app/build.gradle.kts
#  create mode 100644 app/src/androidTest/kotlin/com/dopaminecat/HiltTestRunner.kt
#  create mode 100644 app/src/androidTest/kotlin/com/dopaminecat/di/TestDatabaseModule.kt
# ...

# %%
                                                                                                                     
  # !cd /home/jovyan/work/DopamineCat && git add \            
    app/src/main/kotlin/com/dopaminecat/domain/model/ExceededGoal.kt \                                                     
    app/src/main/kotlin/com/dopaminecat/domain/usecase/ObserveCatStateUseCase.kt \
    app/src/main/kotlin/com/dopaminecat/domain/usecase/CheckGoalExceedUseCase.kt \                                         
    app/src/main/kotlin/com/dopaminecat/domain/usecase/ClaimMidnightRewardUseCase.kt \                                     
    app/src/test/kotlin/com/dopaminecat/domain/usecase/ObserveCatStateUseCaseTest.kt \                                     
    app/src/test/kotlin/com/dopaminecat/domain/usecase/CheckGoalExceedUseCaseTest.kt \                                     
    app/src/test/kotlin/com/dopaminecat/domain/usecase/ClaimMidnightRewardUseCaseTest.kt                                   
                                                                                                                           
  # !cd /home/jovyan/work/DopamineCat && git commit -m "feat: add Domain UseCase layer (ObserveCatState, CheckGoalExceed,    
  ClaimMidnightReward)"
# Out:
#   Cell In[3], line 2
#     app/src/main/kotlin/com/dopaminecat/domain/model/ExceededGoal.kt \
#     ^
# IndentationError: unexpected indent

# %%
# %%bash
# cd /home/jovyan/work/DopamineCat
# git add \
#   app/src/main/kotlin/com/dopaminecat/domain/model/ExceededGoal.kt \
#   app/src/main/kotlin/com/dopaminecat/domain/usecase/ObserveCatStateUseCase.kt \
#   app/src/main/kotlin/com/dopaminecat/domain/usecase/CheckGoalExceedUseCase.kt \
#   app/src/main/kotlin/com/dopaminecat/domain/usecase/ClaimMidnightRewardUseCase.kt \
#   app/src/test/kotlin/com/dopaminecat/domain/usecase/ObserveCatStateUseCaseTest.kt \
#   app/src/test/kotlin/com/dopaminecat/domain/usecase/CheckGoalExceedUseCaseTest.kt \
#   app/src/test/kotlin/com/dopaminecat/domain/usecase/ClaimMidnightRewardUseCaseTest.kt
#
# git commit -m "feat: add Domain UseCase layer (ObserveCatState, CheckGoalExceed, ClaimMidnightReward)"
# Out:
# [main 88a505a] feat: add Domain UseCase layer (ObserveCatState, CheckGoalExceed, ClaimMidnightReward)
#  7 files changed, 624 insertions(+)
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/domain/model/ExceededGoal.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/domain/usecase/CheckGoalExceedUseCase.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/domain/usecase/ClaimMidnightRewardUseCase.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/domain/usecase/ObserveCatStateUseCase.kt
#  create mode 100644 app/src/test/kotlin/com/dopaminecat/domain/usecase/CheckGoalExceedUseCaseTest.kt
#  create mode 100644 app/src/test/kotlin/com/dopaminecat/domain/usecase/ClaimMidnightRewardUseCaseTest.kt
#  create mode 100644 app/src/test/kotlin/com/dopaminecat/domain/usecase/ObserveCatStateUseCaseTest.kt

# %%
# !git log --oneline -n 3
# !git show --stat
# !git status
# Out:
# 88a505a (HEAD -> main) feat: add Domain UseCase layer (ObserveCatState, CheckGoalExceed, ClaimMidnightReward)
# 69b217c (origin/main) chore: 프로젝트 초기 세팅 및 A단계 완료
# commit 88a505ad3f1549cb7b0d42ecf8a4e4a254463d57 (HEAD -> main)
# Author: jjeong <dattery528@gmail.com>
# Date:   Sun May 10 19:13:50 2026 +0900
#
#     feat: add Domain UseCase layer (ObserveCatState, CheckGoalExceed, ClaimMidnightReward)
#
#  .../com/dopaminecat/domain/model/ExceededGoal.kt   |  12 ++
#  .../domain/usecase/CheckGoalExceedUseCase.kt       |  89 +++++++++++
#  .../domain/usecase/ClaimMidnightRewardUseCase.kt   | 102 ++++++++++++
#  .../domain/usecase/ObserveCatStateUseCase.kt       |  19 +++
#  .../domain/usecase/CheckGoalExceedUseCaseTest.kt   | 171 ++++++++++++++++++++
#  .../usecase/ClaimMidnightRewardUseCaseTest.kt      | 175 +++++++++++++++++++++
#  .../domain/usecase/ObserveCatStateUseCaseTest.kt   |  56 +++++++
#  7 files changed, 624 insertions(+)
# 현재 브랜치 main
# 커밋하도록 정하지 않은 변경 사항:
# ...

# %%
# %%bash
#   cd /home/jovyan/work/DopamineCat
#   git add .
#   git commit -m "feat: add UsageTrackingService, MidnightRewardWorker, BootReceiver and ServiceModule"
# Out:
# [main b478f67] feat: add UsageTrackingService, MidnightRewardWorker, BootReceiver and ServiceModule
#  9 files changed, 654 insertions(+), 25 deletions(-)
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/data/receiver/BootReceiver.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/data/service/NotificationHelper.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/data/service/UsageTrackingService.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/data/worker/MidnightRewardWorker.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/data/worker/WorkScheduler.kt
#  create mode 100644 app/src/main/kotlin/com/dopaminecat/di/ServiceModule.kt

# %%
# !git log --oneline -n 3
# !git show --stat
# !git status
# Out:
# b478f67 (HEAD -> main) feat: add UsageTrackingService, MidnightRewardWorker, BootReceiver and ServiceModule
# 88a505a feat: add Domain UseCase layer (ObserveCatState, CheckGoalExceed, ClaimMidnightReward)
# 69b217c (origin/main) chore: 프로젝트 초기 세팅 및 A단계 완료
# commit b478f671cd760df3647f135e8ba627bb41ae0b18 (HEAD -> main)
# Author: jjeong <dattery528@gmail.com>
# Date:   Sun May 10 19:33:02 2026 +0900
#
#     feat: add UsageTrackingService, MidnightRewardWorker, BootReceiver and ServiceModule
#
#  Untitled.ipynb                                     | 215 ++++++++++++++++++++-
#  app/src/main/AndroidManifest.xml                   |  38 ++--
#  .../com/dopaminecat/DopamineCatApplication.kt      |  24 ++-
#  .../com/dopaminecat/data/receiver/BootReceiver.kt  |  41 ++++
#  .../dopaminecat/data/service/NotificationHelper.kt | 107 ++++++++++
#  .../data/service/UsageTrackingService.kt           | 100 ++++++++++
#  .../data/worker/MidnightRewardWorker.kt            |  75 +++++++
# ...
